# %%
n = 1
while n <= 5:
    print('Kamran')
    n += 1
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
n = 1
while n <= 5:
    print('Kamran')
    n++
# Out:
#   Cell In[3], line 4
#     n++
#        ^
# SyntaxError: invalid syntax

# %%
n = 1
while n <= 5:
    print('Kamran')
    n += 1
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
n = 1
while n <= 10:
    print('Kamran')
    n += 2
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
n = -9
while n <= 10:
    print('Kamran')
    n += 2
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
n = 0.5
while n <= 5:
    print('Kamran')
    n += 0.5
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
#range(start, end, step)
list(range(0, 5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(0, 10, 2))
# Out:
# [0, 2, 4, 6, 8]

# %%
for x in range(0, 5):
    print('Kamran')
# Out:
# Kamran
# Kamran
# Kamran
# Kamran
# Kamran

# %%
for x in [1, 1, 1, 1, 1]:
    print(x, 'Kamran')
# Out:
# 1 Kamran
# 1 Kamran
# 1 Kamran
# 1 Kamran
# 1 Kamran

# %%
for x in ['A', 'B', 'C', 1, 1]:
    print(x, 'Kamran')
# Out:
# A Kamran
# B Kamran
# C Kamran
# 1 Kamran
# 1 Kamran
