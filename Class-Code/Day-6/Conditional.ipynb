# %%
marks = int(input('Enter your Marks:'))
if marks >= 33:
    print('Pass')
    
print('Welcome')
# Out:
# Enter your Marks: 23
# Welcome

# %%
marks = int(input('Enter your Marks:'))
if marks >= 33:
    print('Pass')
else:
    print('Fail')
    
print('Welcome')
# Out:
# Enter your Marks: 23
# Fail
# Welcome

# %%
marks = int(input('Enter your Marks:'))
if marks >= 33:
    print('Pass')
else:
    print('Fail')
  
    
print('Welcome')
# Out:
# Enter your Marks: 23
# Fail
# Welcome

# %%
temp = int(input('Enter the temperature in Celsuis:'))
if temp <= 20:
    print('Cold Day')
elif temp > 20 and temp <= 25:
    print('Pleasant day')
else:
    print('Hot Day')
# Out:
# Enter the temperature in Celsuis: 34
# Hot Day

# %%
temp = int(input('Enter the temperature in Celsuis:'))
if temp <= 20:
    print('Cold Day')
elif 20 < temp <= 25:
    print('Pleasant day')
else:
    print('Hot Day')
# Out:
# Enter the temperature in Celsuis: 23
# Pleasant day

# %%
eng = input('Enter the status of English Test (pass/fail):')
if eng == 'pass':
    math = input('Enter the status of Math Test (pass/fail):')
    if math == 'pass':
        print('Admission successful..')
    else:
        print('Try again')
else:
    print('You are not eligible')
# Out:
# Enter the status of English Test (pass/fail): fail
# You are not eligible
