# %%
fruits = ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
# varaible[start(default = 0): end(default = total length of list): step(default=1)]
fruits[4]
# Out:
# 'orange'

# %%
fruits[-2]
# Out:
# 'almond'

# %%
fruits[2: 5]
# Out:
# ['cherry', 'mango', 'orange']

# %%
fruits[-2: 6]
# Out:
# ['almond']

# %%
fruits[-2: 4]
# Out:
# []

# %%
fruits[2 :: 2]
# Out:
# ['cherry', 'orange', 'melon']

# %%
# updating list
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[2] = 'watermelon'

# %%
fruits
# Out:
# ['apple', 'banana', 'watermelon', 'mango', 'orange', 'almond', 'melon']

# %%
fruits[1: 3] = ['grapes', 'stawberry']

# %%
fruits
# Out:
# ['apple', 'grapes', 'stawberry', 'mango', 'orange', 'almond', 'melon']

# %%
fruits.insert(1, 'banana')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'grapes',
#  'stawberry',
#  'mango',
#  'orange',
#  'almond',
#  'melon']

# %%
fruits.append('cherry')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'grapes',
#  'stawberry',
#  'mango',
#  'orange',
#  'almond',
#  'melon',
#  'cherry']

# %%
fruits.remove('almond')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'grapes',
#  'stawberry',
#  'mango',
#  'orange',
#  'melon',
#  'cherry']

# %%
fruits.pop(-2)
# Out:
# 'melon'

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'stawberry', 'mango', 'orange', 'cherry']

# %%
deleted_item = fruits.pop(-2)

# %%
deleted_item
# Out:
# 'orange'

# %%
fruits.append(deleted_item)

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'stawberry', 'mango', 'cherry', 'orange']

# %%
# extend()

product1 = ['Mobile', 'telephone', 'airbods']
product2 = ['shirts', 'hoddies', 'jeans']

product1.extend(product2)
print(product1)
# Out:
# ['Mobile', 'telephone', 'airbods', 'shirts', 'hoddies', 'jeans']

# %%
product2
# Out:
# ['shirts', 'hoddies', 'jeans']

# %%
fruits = ['guava', 'cherry', 'almond', 'apple', 'grapes']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['almond', 'apple', 'cherry', 'grapes', 'guava']

# %%
fruits = ['guava', 'Strawbery', 'almond', 'apple', 'grapes']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['Strawbery', 'almond', 'apple', 'grapes', 'guava']

# %%
fruits = ['guava', 'cherry', 'almond', 'apple', 'grapes']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['guava', 'grapes', 'cherry', 'apple', 'almond']

# %%
fruits = ['guava', 'cherry', 'almond', 'apple', 'grapes']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['grapes', 'apple', 'almond', 'cherry', 'guava']

# %% [markdown]
# ### Is Operator

# %%
x = [20, 30, 40, 50]

# %%
y = [20, 30, 40, 50]

# %%
x is y
# Out:
# False

# %%
z = x

# %%
z
# Out:
# [20, 30, 40, 50]

# %%
x is z
# Out:
# True

# %%
x.append(100)

# %%
x
# Out:
# [20, 30, 40, 50, 100]

# %%
z
# Out:
# [20, 30, 40, 50, 100]

# %%
t = x.copy()

# %%
t
# Out:
# [20, 30, 40, 50, 100]

# %%
x.append(200)

# %%
x
# Out:
# [20, 30, 40, 50, 100, 200]

# %%
t
# Out:
# [20, 30, 40, 50, 100]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange', 'almond', 'melon']

# %%
s = fruits[2]

# %%
s[2]
# Out:
# 'e'

# %%
fruits[2][0: 3][1][0]
# Out:
# 'h'

# %%
# 2D List
fruits_veg = [['apple', 'banana', 'cherry'], ['Brinjal', 'Potato', 'Radish']]
print(fruits_veg)
# Out:
# [['apple', 'banana', 'cherry'], ['Brinjal', 'Potato', 'Radish']]

# %%
fruits_2d = ['apple', 'banana', ['cherry', 'melon'], 'grapes']

# %%
fruits_2d[2][1][3]
# Out:
# 'o'
