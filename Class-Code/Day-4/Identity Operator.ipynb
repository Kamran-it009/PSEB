# %%
x = 3
y = 3

# %%
print(id(x))
# Out:
# 140722606994408

# %%
print(id(y))
# Out:
# 140722606994408

# %%
a = -10
b = -10
print(id(a))
print(id(b))
# Out:
# 2148321698992
# 2148321698608

# %%
x = x + 1

# %%
x
# Out:
# 4

# %%
y
# Out:
# 3

# %%
print(id(x))
print(id(y))
# Out:
# 140722606994440
# 140722606994408

# %%
# Is operator
x is y
# Out:
# False
