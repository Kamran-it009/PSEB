# %%
print('Hello! My name is Kamran.)
# Out:
#   Cell In[2], line 1
#     print('Hello! My name is Kamran.)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello! My name is Kamran.'
# Out:
#   Cell In[3], line 1
#     print('Hello! My name is Kamran.'
#                                      ^
# _IncompleteInputError: incomplete input

# %%
prnt('Hello! My name is Kamran.')
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 prnt('Hello! My name is Kamran.')
#
# NameError: name 'prnt' is not defined

# %%
x = '5'
y = 2
print(x + y)
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 x = '5'
#       2 y = 2
# ----> 3 print(x + y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
import math
print(math.sqrt(-4))
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[7], line 2
#       1 import math
# ----> 2 print(math.sqrt(-4))
#
# ValueError: math domain error

# %%
print('Muhammad')
result = 10/0
print('Kamran')
print('Khan')
# Out:
# Muhammad
# ------------------------------------------------------------------------
# ZeroDivisionError                      Traceback (most recent call last)
# Cell In[9], line 2
#       1 print('Muhammad')
# ----> 2 result = 10/0
#       3 print('Kamran')
#       4 print('Khan')
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 10/2
    print(result)
except:
    print('Kamran')
    print('Khan')
# Out:
# 5.0

# %%
try:
    result = 10/0
    print(result)
    print('Kamran')
    print('Khan')
except:
    print('Error Found')
# Out:
# Error Found

# %%
try:
    reults = 10/2
    prin('Kamran')
except ZeroDivisionError as e:
    print('Error found:', str(e))
except NameError as n:
    print('Error found:', str(n))
# Out:
# Error found: name 'prin' is not defined

# %%
try:
    x = 10
    y = 2
    result = x / y
except ZeroDivisionError as e:
    print("Caught a ZeroDivisionError:", str(e))
else:
    print("Division successful:", result)
finally:
    print("Thank you")
# Out:
# Division successful: 5.0
# Thank you
