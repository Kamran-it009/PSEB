# %%
file = open(mode = 'r', file = 'data.txt')

# %%
data_file = open('data.txt')
print(file)
# Out:
# <_io.TextIOWrapper name='data.txt' mode='r' encoding='cp1252'>

# %%
data_file.read()
# Out:
# 'Pakistan is an agricultural land.'

# %%
data_file.read()
# Out:
# ''

# %%
data_file.seek(0)
# Out:
# 0

# %%
data_file.read()
# Out:
# 'Pakistan is an agricultural land.'

# %%
data_file.seek(0)
# Out:
# 0

# %%
data_file.readline()
# Out:
# 'Pakistan is an agricultural land.\n'

# %%
data_file.readline()
# Out:
# 'Pakistan is a muslim country.\n'

# %%
data_file.readline()
# Out:
# 'Pakistan is a democratic country.\n'

# %%
lines = data_file.readlines()

# %%
lines
# Out:
# ['Pakistan is an agricultural land.\n',
#  'Pakistan is a muslim country.\n',
#  'Pakistan is a democratic country.\n',
#  'Pakistan has automic power.\n']

# %%
data_file.seek(0)
# Out:
# 0

# %%
data_file.close()

# %%
data_file.read()
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data_file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('data.txt', mode = 'r') as data_file:
    print(data_file.readlines())
# Out:
# ['Pakistan is an agricultural land.\n', 'Pakistan is a muslim country.\n', 'Pakistan is a democratic country.\n', 'Pakistan has automic power.\n']

# %%
data_file.read()
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data_file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('data.txt', mode = 'w') as data_file:
    data_file.write('My name is Muhammad Kamran Khan.')

# %%
with open('data.txt', mode = 'a') as data_file:
    data_file.write('\nPakistan is an agricultural land.')
