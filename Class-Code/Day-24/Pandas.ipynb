# %%
import numpy as np
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
my_list = ['apple', 'banana', 'cherry']
ser = pd.Series(my_list)

# %%
print(ser)
# Out:
# 0     apple
# 1    banana
# 2    cherry
# dtype: object

# %%
ser[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ser[-1]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
# ...

# %%
my_list = ['apple', 'banana', 'cherry']
ser = pd.Series(my_list, index = ['A', 'B', 'C'])

# %%
print(ser)
# Out:
# A     apple
# B    banana
# C    cherry
# dtype: object

# %%
ser['A']
# Out:
# 'apple'

# %%
ser['A': 'C']
# Out:
# A     apple
# B    banana
# C    cherry
# dtype: object

# %%
ser[-'C']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ser[-'C']
#
# TypeError: bad operand type for unary -: 'str'

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])    
print(ser1)
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])  
print(ser2)
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
# DataFrames
students = {'Roll_no': [101, 102, 103, 104, 105],
           'Name': ['Ali', 'Ahmad', 'Umer', 'Zubair', 'Tayyab'],
           'Subject': ['OOP', 'Database', 'Software Engineering', 'OS', 'Programing'],
           'Marks': [80, 87, 67, 56, 92]}

# %%
students
# Out:
# {'Roll_no': [101, 102, 103, 104, 105],
#  'Name': ['Ali', 'Ahmad', 'Umer', 'Zubair', 'Tayyab'],
#  'Subject': ['OOP', 'Database', 'Software Engineering', 'OS', 'Programing'],
#  'Marks': [80, 87, 67, 56, 92]}

# %%
df_student = pd.DataFrame(students)

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df_student['Roll_no']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: Roll_no, dtype: int64

# %%
df_student[0]
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_student[0]
#
# ...

# %%
df_student[['Roll_no', 'Name', 'Marks']]
# Out:
#    Roll_no    Name  Marks
# 0      101     Ali     80
# 1      102   Ahmad     87
# 2      103    Umer     67
# 3      104  Zubair     56
# 4      105  Tayyab     92

# %%
df_student['Percentage'] = df_student['Marks']/200 * 100

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 1      102   Ahmad              Database     87        43.5
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_student.drop('Percentage')
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_student.drop('Percentage')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df_student.drop(1)
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_student.drop('Percentage', axis = 1)
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df_student.drop(columns = ['Percentage'])
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 1      102   Ahmad              Database     87        43.5
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_update = df_student.drop('Percentage', axis = 1)

# %%
df_update
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 1      102   Ahmad              Database     87        43.5
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_student.drop('Percentage', axis = 1, inplace=True)

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df_student.drop(columns=['Percentage', 'Marks', 'Name'])
# Out:
#    Roll_no               Subject
# 0      101                   OOP
# 1      102              Database
# 2      103  Software Engineering
# 3      104                    OS
# 4      105            Programing

# %%
df_student.drop([1, 2, 4])
# Out:
#    Roll_no    Name Subject  Marks  Percentage
# 0      101     Ali     OOP     80        40.0
# 3      104  Zubair      OS     56        28.0

# %%
df_student.drop([1: 3])
# Out:
#   Cell In[25], line 1
#     df_student.drop([1: 3])
#                       ^
# SyntaxError: invalid syntax

# %%
df_update2 = df_student.drop([1, 2, 4])

# %%
df_update2
# Out:
#    Roll_no    Name Subject  Marks  Percentage
# 0      101     Ali     OOP     80        40.0
# 3      104  Zubair      OS     56        28.0

# %%
df_update3 = df_update2.reset_index()

# %%
df_update3 = df_update3.drop('index', axis = 1)

# %%
df_update3
# Out:
#    Roll_no    Name Subject  Marks  Percentage
# 0      101     Ali     OOP     80        40.0
# 1      104  Zubair      OS     56        28.0

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 1      102   Ahmad              Database     87        43.5
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_student2 = df_student.set_index('Roll_no')

# %%
df_student2
# Out:
#            Name               Subject  Marks  Percentage
# Roll_no
# 101         Ali                   OOP     80        40.0
# 102       Ahmad              Database     87        43.5
# 103        Umer  Software Engineering     67        33.5
# 104      Zubair                    OS     56        28.0
# 105      Tayyab            Programing     92        46.0

# %%
df_student2.drop([102, 105])
# Out:
#            Name               Subject  Marks  Percentage
# Roll_no
# 101         Ali                   OOP     80        40.0
# 103        Umer  Software Engineering     67        33.5
# 104      Zubair                    OS     56        28.0

# %%
df_student2.drop()
# Out:
# --------------------------------------------------------------
# ValueError                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20084\2689632131.py in ?()
# ----> 1 df_student2.drop()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4776             axes = {"index": index}
#    4777             if self.ndim == 2:
#    4778                 axes["columns"] = columns
#    4779         else:
# ...

# %%
# loc[row, col]
# iloc

df_student2.loc[103]
# Out:
# Name                          Umer
# Subject       Software Engineering
# Marks                           67
# Percentage                    33.5
# Name: 103, dtype: object

# %%
df_student2.loc[103: 105]
# Out:
#            Name               Subject  Marks  Percentage
# Roll_no
# 103        Umer  Software Engineering     67        33.5
# 104      Zubair                    OS     56        28.0
# 105      Tayyab            Programing     92        46.0

# %%
df_student2.loc[103: 105, 'Marks']
# Out:
# Roll_no
# 103    67
# 104    56
# 105    92
# Name: Marks, dtype: int64

# %%
df_student2.loc[[103, 105, 102], 'Marks']
# Out:
# Roll_no
# 103    67
# 105    92
# 102    87
# Name: Marks, dtype: int64

# %%
df_student2.loc[103: 105, ['Subject', 'Marks']]
# Out:
#                       Subject  Marks
# Roll_no
# 103      Software Engineering     67
# 104                        OS     56
# 105                Programing     92

# %%
df_student2[['Subject', 'Marks']].loc[103: 105]
# Out:
#                       Subject  Marks
# Roll_no
# 103      Software Engineering     67
# 104                        OS     56
# 105                Programing     92

# %%
df_student2[['Subject', 'Marks']].tail(3)
# Out:
#                       Subject  Marks
# Roll_no
# 103      Software Engineering     67
# 104                        OS     56
# 105                Programing     92

# %%
df_student2.iloc[1:3, [2, 3]]
# Out:
#          Marks  Percentage
# Roll_no
# 102         87        43.5
# 103         67        33.5

# %%
df_student
# Out:
#    Roll_no    Name               Subject  Marks  Percentage
# 0      101     Ali                   OOP     80        40.0
# 1      102   Ahmad              Database     87        43.5
# 2      103    Umer  Software Engineering     67        33.5
# 3      104  Zubair                    OS     56        28.0
# 4      105  Tayyab            Programing     92        46.0

# %%
df_student[df_student['Percentage'] > 40]
# Out:
#    Roll_no    Name     Subject  Marks  Percentage
# 1      102   Ahmad    Database     87        43.5
# 4      105  Tayyab  Programing     92        46.0

# %%
df_student[df_student['Percentage'] > 40].loc[:, ['Roll_no', 'Name']]
# Out:
#    Roll_no    Name
# 1      102   Ahmad
# 4      105  Tayyab

# %%
pd.read_
