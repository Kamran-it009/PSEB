# %%
vegetables = ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage')
print(vegetables)
# Out:
# ('Potato', 'Spinish', 'Carrot', 'Onion', 'Garlic', 'Cabbage')

# %%
ranom = (10, 'carrot', 34.5)
print(ranom)
# Out:
# (10, 'carrot', 34.5)

# %%
vegetables[2]
# Out:
# 'Carrot'

# %%
vegetables[-2]
# Out:
# 'Garlic'

# %%
vegetables[2: 6]
# Out:
# ('Carrot', 'Onion', 'Garlic', 'Cabbage')

# %% [markdown]
# ### Mutable Vs Immutable

# %%
vegetables.append('Cauli flower')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vegetables.append('Cauli flower')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
vegetables[-2] = 'Cauliflower'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 vegetables[-2] = 'Cauliflower'
#
# TypeError: 'tuple' object does not support item assignment

# %%
vegetables.index('Garlic')
# Out:
# 4

# %%
vegetables.count('Garlic')
# Out:
# 1

# %% [markdown]
# ## Dictionaries

# %%
# Creating a Dictionary
fruits_dict = {'A': 'apple', 'B': 'banana', 
               'C': 'cherry', 'D': 'Dragon fruits'}
print(fruits_dict)
# Out:
# {'A': 'apple', 'B': 'banana', 'C': 'cherry', 'D': 'Dragon fruits'}

# %%
fruits_dict['A']
# Out:
# 'apple'

# %%
fruits_dict[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fruits_dict[2]
#
# KeyError: 2

# %%
fruits_dict['A': 'C']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fruits_dict['A': 'C']
#
# KeyError: slice('A', 'C', None)

# %%
veg = { 'names': ['kamran', 'ali', 'hassan'], 
      'age': [34, 56, 31]
      }

# %%
veg2 = {'employee': {'name': 'kamran'}, 'department': {'section': 'A'}}

# %%
veg2['employee']['name']
# Out:
# 'kamran'

# %%
veg['names'][-1]
# Out:
# 'hassan'

# %%
new = dict.fromkeys(vegetables, 0)

# %%
new
# Out:
# {'Potato': 0, 'Spinish': 0, 'Carrot': 0, 'Onion': 0, 'Garlic': 0, 'Cabbage': 0}

# %%
fruits_dict.get('A')
# Out:
# 'apple'

# %%
fruits_dict.values()
# Out:
# dict_values(['apple', 'banana', 'cherry', 'Dragon fruits'])

# %% [markdown]
# ## Sets

# %%
# Set Creation
fruits = {'apple', 'banana', 'cherry', 'orange', 'melon', 'watermelon'}
print(fruits)
# Out:
# {'cherry', 'banana', 'watermelon', 'orange', 'melon', 'apple'}

# %%
print(fruits)
# Out:
# {'cherry', 'banana', 'watermelon', 'orange', 'melon', 'apple'}

# %%
fruits = {'apple', 'banana', 'cherry', 'orange', 'watermelon'}
print(fruits)
# Out:
# {'cherry', 'banana', 'watermelon', 'orange', 'apple'}

# %%
fruits2 = {'apple', 'banana', 'cherry', 'orange', 'melon', 'watermelon'}
print(fruits2)
# Out:
# {'orange', 'watermelon', 'melon', 'cherry', 'apple', 'banana'}

# %%
fruits3 = {'apple', 'apple', 'banana', 'cherry', 'orange', 'melon', 'watermelon'}

# %%
fruits3
# Out:
# {'apple', 'banana', 'cherry', 'melon', 'orange', 'watermelon'}

# %%
fruits3.
