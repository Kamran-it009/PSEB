# %% [markdown]
# ### Strings

# %%
name = 'Muhammad Kamran Khan'

# %%
print(name)
# Out:
# Muhammad Kamran Khan

# %%
name[9]
# Out:
# 'K'

# %%
name[-2]
# Out:
# 'a'

# %% [markdown]
# ##### variable[start(default=0): end(default=length of string): step(default=1)]

# %%
name[9:15]
# Out:
# 'Kamran'

# %%
name[-5:-1]
# Out:
# ' Kha'

# %%
name[-4:-1]
# Out:
# 'Kha'

# %%
name[-4:]
# Out:
# 'Khan'

# %%
len(name)
# Out:
# 20

# %%
name[-4:20]
# Out:
# 'Khan'

# %%
name
# Out:
# 'Muhammad Kamran Khan'

# %%
name[-2: 7]
# Out:
# ''

# %%
name[9: 15: 2]
# Out:
# 'Kma'

# %%
name[9: 15: -1]
# Out:
# ''

# %% [markdown]
# ### String methods

# %%
len(name)
# Out:
# 20

# %%
name.capitalize()
# Out:
# 'Muhammad kamran khan'

# %%
name.upper()
# Out:
# 'MUHAMMAD KAMRAN KHAN'

# %%
name.lower()
# Out:
# 'muhammad kamran khan'

# %%
name.split()
# Out:
# ['Muhammad', 'Kamran', 'Khan']

# %%
name2 = 'Muhammad-Kamran-Khan'

# %%
name2.split('-')
# Out:
# ['Muhammad', 'Kamran', 'Khan']

# %%
name
# Out:
# 'Muhammad Kamran Khan'

# %%
name.split('K')
# Out:
# ['Muhammad ', 'amran ', 'han']

# %%
name.split()
# Out:
# ['Muhammad', 'Kamran', 'Khan']

# %%
name.title()
# Out:
# 'Muhammad Kamran Khan'

# %%
name2 = 'Muhammad-kamran-khan'

# %%
name2.title()
# Out:
# 'Muhammad-Kamran-Khan'

# %%
name2 = 'Muhammad@kamran@khan'

# %%
name2.title()
# Out:
# 'Muhammad@Kamran@Khan'

# %%
name3 = 'MuhammadIkamranIkhan'

# %%
name3.title()
# Out:
# 'Muhammadikamranikhan'

# %%
words = name.split()

# %%
words
# Out:
# ['Muhammad', 'Kamran', 'Khan']

# %%
'--'.join(words)
# Out:
# 'Muhammad--Kamran--Khan'

# %%
''.join(words)
# Out:
# 'MuhammadKamranKhan'

# %%
name.find('Kamran')
# Out:
# 9

# %%
name.find('kamran')
# Out:
# -1

# %%
name.find('K')
# Out:
# 9

# %%
name.count('K')
# Out:
# 2

# %%
name4 = 'Muhammad Ali Khan and Kamran Khan'

# %%
name4.replace('Khan', 'Developer')
# Out:
# 'Muhammad Ali Developer and Kamran Developer'

# %%
name.startswith('Muhammad')
# Out:
# True

# %%
name.startswith('Ali')
# Out:
# False

# %%
new = name[9: 15]
new[::-1]
# Out:
# 'narmaK'

# %%
name
# Out:
# 'Muhammad Kamran Khan'

# %%
'Khan' in name
# Out:
# True

# %%
age = 14
height = 5.4

# %%
print('My name is %s and my age is %d and my height is %f' %(name, age, height))
# Out:
# My name is Muhammad Kamran Khan and my age is 14 and my height is 5.400000

# %%
'banana' > 'apples'
# Out:
# True
