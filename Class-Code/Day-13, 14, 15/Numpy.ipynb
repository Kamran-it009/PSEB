# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.2.4

# %%
fruits = ['apple', 'mango', 'banana']
print('List:',fruits)
arr = np.array(fruits)
print('\nArray:', arr)
# Out:
# List: ['apple', 'mango', 'banana']
#
# Array: ['apple' 'mango' 'banana']

# %%
print('Type of Array:', type(arr))
# Out:
# Type of Array: <class 'numpy.ndarray'>

# %%
fruits = ('apple', 'mango', 'banana')
print('Tuple:', fruits)
arr = np.array(fruits)
print('\nArray:', arr)
# Out:
# Tuple: ('apple', 'mango', 'banana')
#
# Array: ['apple' 'mango' 'banana']

# %%
fruits_dict = {'A': 'apple', 'B': 'banana', 'C': 'cherry'}
print(fruits_dict)
# Out:
# {'A': 'apple', 'B': 'banana', 'C': 'cherry'}

# %%
arr2 = np.array(fruits_dict)
print(arr2)
# Out:
# {'A': 'apple', 'B': 'banana', 'C': 'cherry'}

# %%
print(type(arr2))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr2)
# Out:
# {'A': 'apple', 'B': 'banana', 'C': 'cherry'}

# %%
print(arr[1])
# Out:
# mango

# %%
fruits = [2, 'apple', 3.0]
print(fruits)
# Out:
# [2, 'apple', 3.0]

# %%
new_arr = np.array(fruits)
print(new_arr)
# Out:
# ['2' 'apple' '3.0']

# %%
arr3 = np.array([2, 4, 6])
print(arr3)
print(arr3.dtype)
# Out:
# [2 4 6]
# int64

# %%
arr = np.array([23, 45, 67], dtype = 'int8')

# %%
print(arr)
# Out:
# [23 45 67]

# %%
arr = np.array([250, 45, 67], dtype = 'int8')
print(arr)
# Out:
# -------------------------------------------
# OverflowErrorTraceback (most recent call last)
# Cell In[25], line 1
# ----> 1 arr = np.array([250, 45, 67], dtype = 'int8')
#       2 print(arr)
#
# OverflowError: Python integer 250 out of bounds for int8

# %%
arr = np.array(['apple', 'banana'])
print(arr.dtype)
# Out:
# <U6

# %%
fruits = np.array([2, 'dragon apple aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa', 3.0])
print(fruits.dtype)
# Out:
# <U64

# %%
arr1 = np.array(34)
print(arr1)
print('Dimension:', arr1.ndim)
# Out:
# 34
# Dimension: 0

# %%
arr3 = np.array([152, 10, 90], dtype = 'int8')
print(arr3)
print(arr3.dtype)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 arr3 = np.array([152, 10, 90], dtype = 'int8')
#       2 print(arr3)
#       3 print(arr3.dtype)
#
# OverflowError: Python integer 152 out of bounds for int8

# %%
arr = np.array([1, 2, 3, 4, 5])
reshaped = arr.reshape(5, 2)
print('Original array:', arr)
print('Reshaped array:\n', reshaped)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 arr = np.array([1, 2, 3, 4, 5])
# ----> 2 reshaped = arr.reshape(5, 2)
#       3 print('Original array:', arr)
#       4 print('Reshaped array:\n', reshaped)
#
# ValueError: cannot reshape array of size 5 into shape (5,2)

# %%
arr = np.array(['apple', 'banana'])
print(arr.max())
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 arr = np.array(['apple', 'banana'])
# ----> 2 print(arr.max())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\_methods.py:44, in _amax(a, axis, out, keepdims, initial, where)
#      42 def _amax(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# UFuncTypeError: ufunc 'maximum' did not contain a loop with signature matching types (dtype('<U6'), dtype('<U6')) -> None
