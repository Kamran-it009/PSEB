# %%
class Person:
    name = 'Hussain'
    age = 34

    def walk(self):
        print('Walking..')

    def jump(self):
        print('Jumping')

    def talk(self):
        print('Talking')

# %%
p1 = Person()

# %%
print(p1)
# Out:
# <__main__.Person object at 0x000001B9FD755400>

# %%
p1.age
# Out:
# 34

# %%
p1.jump()
# Out:
# Jumping

# %%
p1.walk()
# Out:
# Walking..

# %%
class Human:
    name = 'Hassan'
    age = 30

    def walk():
        print('Walking..')

    def jump():
        print('Jumping')

    def talk():
        print('Talking')

# %%
Human.talk()
# Out:
# Talking

# %%
Human.age
# Out:
# 30

# %%
h1 = Human()

# %%
h1.walk()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 h1.walk()
#
# TypeError: Human.walk() takes 0 positional arguments but 1 was given

# %%
h1.talk()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 h1.talk()
#
# TypeError: Human.talk() takes 0 positional arguments but 1 was given

# %%
Human.walk()
# Out:
# Walking..

# %%
h1.age
# Out:
# 30

# %%
Human.age
# Out:
# 30

# %%
class Species:
    name = 'Hassan'
    age = 30

    def walk(self):
        print('Walking..')

    def jump():
        print('Jumping')

    def talk():
        print('Talking')

# %%
s1 = Species()

# %%
s1.walk()
# Out:
# Walking..

# %%
s1.jump()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s1.jump()
#
# TypeError: Species.jump() takes 0 positional arguments but 1 was given

# %%
Species.jump()
# Out:
# Jumping

# %%
dir(Human)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'jump',
#  'name',
#  'talk',
#  'walk']

# %%
type(p1)
# Out:
# __main__.Person

# %%
type(h1)
# Out:
# __main__.Human

# %%
type(Human)
# Out:
# type

# %%
class Student1:
    name = 'Hussain'
    age = 34
    marks = 340
    roll_no = 101

    def course_register(self):
        print('The student is registering a course..')

    def see_result(self):
        print('The result is displaying..')

    def fee_submission(self):
        print('Student Fee is submitted')

# %%
s1 = Student1()

# %%
class Student2:
    name = 'Ali'
    age = 30
    marks = 323
    roll_no = 102

    def course_register(self):
        print('The student is registering a course..')

    def see_result(self):
        print('The result is displaying..')

    def fee_submission(self):
        print('Student Fee is submitted')

# %%
s2 = Student2()

# %%
class Student:
    def __init__(self, name, roll_no, marks, age):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks
        self.age = age

    def course_register(self):
        print('The student is registering a course..')

    def see_result(self):
        print('The result is displaying..')

    def fee_submission(self):
        print('Student Fee is submitted')

# %%
s1 = Student('Ali', 101, 350, 23)

# %%
s1.name
# Out:
# 'Ali'

# %%
s1.marks
# Out:
# 350

# %%
s2 = Student('Hassan', 102, 230, 24)

# %%
s2.name
# Out:
# 'Hassan'

# %%
dir(Human)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'jump',
#  'name',
#  'talk',
#  'walk']

# %%
dir(Species)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'jump',
#  'name',
#  'talk',
#  'walk']

# %%
class Person:
    # Constructor
    def __init__(self, name):
        self.name = name
        print(f"Constructor: Hello, my name is {self.name}")

    # Destructor
    def __del__(self):
        print(f"Destructor: Goodbye from {self.name}")

# %%
p1 = Person('Kamran')
# Out:
# Constructor: Hello, my name is Kamran

# %%
p1.name
# Out:
# 'Kamran'

# %%
# Out:
# Destructor: Goodbye from Kamran

# %%
p1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 p1
#
# NameError: name 'p1' is not defined

# %%
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
        
    def walk(self):
        print('He is Walking...')

# %%
p1 = Person('Ali', 23, 'male')

# %%
class Student(Person):
    roll_no = 1231
    def register_course(self):
        print('Computer Science course is registered')

# %%
s1 = Student('Hassan', 23, 'male')

# %%
s1.walk()
# Out:
# He is Walking...

# %%
s1.register_course()
# Out:
# Computer Science course is registered

# %%
s1.roll_no
# Out:
# 1231

# %%
# Base class
class Animal:
    def speak(self):
        print("Animal speaks")

# Intermediate class (inherits from Animal)
class Dog(Animal):
    def bark(self):
        print("Dog barks")

# Derived class (inherits from Dog)
class Puppy(Dog):
    def weep(self):
        print("Puppy weeps")

# %%
p1 = Puppy()

# %%
p1.speak()
# Out:
# Animal speaks

# %%
p1.bark()
# Out:
# Dog barks

# %%
p1.weep()
# Out:
# Puppy weeps

# %%
# Base class
class Animal:
    def speak(self):
        print("Animal speaks")

# Derived class 1
class Dog(Animal):
    def bark(self):
        print("Dog barks")

# Derived class 2
class Cat(Animal):
    def meow(self):
        print("Cat meows")

# %%
c1 = Cat()
d1 = Dog()

# %%
c1.speak()
# Out:
# Animal speaks

# %%
d1.speak()
# Out:
# Animal speaks

# %%
# First parent class
class Father:
    def gardening(self):
        print("Father: Gardening")

# Second parent class
class Mother:
    def cooking(self):
        print("Mother: Cooking")

# Child class inheriting from both
class Child(Father, Mother):
    def own_skill(self):
        print("Child: Painting")

# %%
c1 = Child()

# %%
c1.gardening()
# Out:
# Father: Gardening

# %%
c1.cooking()
# Out:
# Mother: Cooking

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):  # Overriding the parent method
        print("Dog barks")

# Create objects
a = Animal()
d = Dog()

# %%
d.sound()
# Out:
# Dog barks

# %%
class Calculator:
    def add(self, a):
        print("Sum:", a + 0 + 0)

    def add(self, a, b, c):
        print("Sum:", a + b + c)

    def add(self, a, b):
        print("Sum:", a + b + 0)

# %%
calc = Calculator()

# %%
calc.add(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 calc.add(2)
#
# TypeError: Calculator.add() missing 1 required positional argument: 'b'

# %%
class Person():
    def __init__(self, name, age, martial_status): # constructor method
        self.name = name # public attribute
        self._age = age # protected attribute
        self.__martial_status = martial_status # private attribute
    
    def walk(self): # class method
        print('The person is walking')

# %%
p1 = Person('Hassan', 20, 'single')

# %%
p1.name
# Out:
# 'Hassan'

# %%
p1._age
# Out:
# 20

# %%
p1.__martial_status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 p1.__martial_status
#
# AttributeError: 'Person' object has no attribute '__martial_status'

# %%
class Person():
    def __init__(self, name, age, martial_status): # constructor method
        self.name = name # public attribute
        self._age = age # protected attribute
        self.__status = martial_status # private attribute
    
    def walk(self): # class method
        print('The person is walking')

    # Getter method
    def get_status(self):
        return self.__status

    # Setter method
    def set_status(self, new_value):
        self.__status = new_value

# %%
p1 = Person('Kashif', 32, 'single')

# %%
p1.__status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 p1.__status
#
# AttributeError: 'Person' object has no attribute '__status'

# %%
p1.get_status()
# Out:
# 'single'

# %%
p1.set_status('married')

# %%
p1.get_status()
# Out:
# 'married'

# %%
class Teacher:
    def register_course(self):
        print('Computer Science course is taught by teacher')

class Student:
    def register_course(self):
        print('Computer Science course is registered')

# %%
teacher1 = Teacher()
student1 = Student()

teacher1.register_course()
student1.register_course()
# Out:
# Computer Science course is taught by teacher
# Computer Science course is registered

# %%
from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):
    
    @abstractmethod
    def sound(self):
        pass  # Abstract method with no body

# Derived class 1
class Dog(Animal):
    def sound(self):
        print("Dog barks")
        

# Derived class 2
class Cat(Animal):
    def sound(self):
        print("Cat meows")

# %%
# Create objects
d = Dog()
c = Cat()

d.sound()  # Output: Dog barks
c.sound()  # Output: Cat meows
# Out:
# Dog barks
# Cat meows

# %%
from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):
    
    @abstractmethod
    def sound(self):
        pass  # Abstract method with no body

    

# Derived class 1
class Dog(Animal):
    def sound(self):
        print("Dog barks")

    def walk():
        print()
        

# Derived class 2
class Cat(Animal):
    def sound(self):
        print("Cat meows")

# %%
d = Dog()

# %%
a = Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a = Animal()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'sound'

# %%
# Class definition
class PlayerCharacter:
    def __init__(self, name, age):
            self.name = name
            self.age = age

    def shout(self):
        print(f'my name is {self.name}')

    # staticmethod     
    @staticmethod
    def jump():
        print('Player is jumping')

# %%
player1 = PlayerCharacter('Asif', 23)

# %%
player1.shout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 player1.shout()
#
# TypeError: PlayerCharacter.shout() missing 1 required positional argument: 'self'

# %%
player1.jump()
# Out:
# Player is jumping

# %%
PlayerCharacter.shout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 PlayerCharacter.shout()
#
# TypeError: PlayerCharacter.shout() missing 1 required positional argument: 'self'

# %%
PlayerCharacter.jump()
# Out:
# Player is jumping

# %%
def __init__():
    print('Walking')

# %%
__init__()
# Out:
# Walking

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def __str__(self):
        return f"Book: {self.title}"

    def __call__(self):
        print(f"Hello, {self.author}!")

    def __repr__(self):
        return f"Info({self.title}, {self.author})"

# %%
b1 = Book('Database', 'Thomas Conolly')

# %%
print(b1)
# Out:
# Book: Database

# %%
b1()
# Out:
# Hello, Thomas Conolly!

# %%
b1
# Out:
# Info(Database, Thomas Conolly)
